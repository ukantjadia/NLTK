# %%
import spacy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
url = '/content/drive/My Drive/NLTK/edited_tweets.csv'
data = pd.read_csv(url)
# Out:
# Mounted at /content/drive

# %%
df = data[['id','content']]

# %%
df.isnull().sum()
# Out:
# id         0
# content    0
# dtype: int64

# %%
  df.dtypes
# Out:
# id          int64
# content    object
# dtype: object

# %%
nlp = spacy.load('en_core_web_sm')

# %%
nlp.components
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7f3e92e40340>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7f3e92e40280>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7f3e92e3ec10>),
#  ('senter', <spacy.pipeline.senter.SentenceRecognizer at 0x7f3e92e26a00>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7f3e92b76bc0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7f3e92adfac0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7f3e92e3e970>)]

# %%
nlp.component_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'senter',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner']

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %% [markdown]
# ### Using Spacy TextBlob: Sentiment Analysis using TextBlob

# %%
# %pip install spacytextblob
from spacytextblob.spacytextblob import SpacyTextBlob

# %%
nlp.add_pipe('spacytextblob')

# %%
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'spacytextblob']

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Working with SpaCy
# - Removing Stopwords
# - Lemmatizing
# - Stemmeing

# %%
tweets = list(data['content'])

# %% [markdown]
# #### Stop words

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
def remove_stop(text):
  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(text.lower())

  res = ""
  for word in word_tokens:
    if word not in stop_words:
      res += f"{word} "
    
  return res

res = []
for tweet in tweets:
  res.append(remove_stop(tweet))

token = pd.Series(res)
df['tokenize'] = token.values

# %% [markdown]
# #### Lemmantization with spacy

# %%
res = []
for tweet in tweets:
  text = tweet
  tokens = nlp(text)
  res_str = ""
  for token in tokens:
    res_str += f" {token.lemma_}"
  res.append(res_str)

df['lemmantize'] = (pd.Series(res)).values
# Out:
# <ipython-input-38-abba2769a873>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lemmantize'] = (pd.Series(res)).values

# %%
from nltk.stem import WordNetLemmatizer 
from nltk.stem import PorterStemmer

res = []
ps = PorterStemmer()

for tweet in tweets:
  test = tweet 
  tokenization = nltk.word_tokenize(text)
  res_str = ""
  for w in tokenization:
    rootWord = ps.stem(w)
    res_str += f" {rootWord}"
  res.append(res_str)

df['Stemmer'] = (pd.Series(res)).values

# %%
docx = nlp(tweets[0])
print(docx._.polarity)
# Out:
# 0.0

# %%
lemman = list(df['lemmantize'])
# Out:
# [' GPT4   GPT4   airdrop       HEX AI   AI   AI',
#  ' ne par l   intelligence   open ai tu te',
#  ' glad to see   GPT4 be 10x now   and still    airdrop      BLUR    DOGE   GPT4',
#  ' wow   just watch the late South Park episode and my be still all the hilarious and clever commentary   can   t believe I    get to write this post about it too',
#  ' struggle to find the perfect   try our prompt generator tool   for endless inspiration   give it a go   marketing',
#  ' gpt4   10    airdrop     AI    PAW   AI   DOGE   APT',
#  ' an interesting read on in journalism by',
#  ' be ready to enter the world of AI     GPT4   airdrop     AI AI GPT4   BONK     GPT4   DOGE   GPT4',
#  ' I en mi    la no usar   el de',
#  ' opinion   Government should go slow when AI ai comment gift article technology',
#  ' plus not work again   it   s down like every weekday',
#  ' sorry    t go anywhere   the good news be that   t necessarily mean the end of learn   some be find way to integrate AI into the classroom   tech',
#  ' 99   99   of the people and   t even know as a non   profit to be with',
#  ' GPT4 AI   airdrop   PAW     GPT4    BONK GPT4      SHI',
#  ' Bard di     che si distingue da di Tech bard',
#  ' try out additive by   it be where you give a set of for   I   e   color   camera angle    and tell it to analyze certain of for those   it   s a great way to generate for AI',
#  ' 4 Thema   den    Social Media      Corona',
#  ' Noun   ocean a giant swimming pool that   s be around for million of and still   t figure out how to clean itself   technology innovation',
#  ' so I write a review of here you be',
#  ' 079   j   ai si un intelligent   la',
#  ' what if Bard stop try to beat and try to be something else   e   g   a   pilot for search I   e   not a classic chat bot   I   e   text only   but would be   chat I   e   a search   pilot   more effective    accurate',
#  ' Bolivar Today   I have a simple exchange with   when it make a mistake   easily spot   it and correct itself   but only after I about the veracity   confirmation of one of its   to err be typical of human intelligence   though',
#  ' GPT4   GPT4   airdrop AI   BONE AI    GPT4   GPT4   APE       PAW',
#  ' GPT4        airdrop      AI   GPT4    SHI   PAW   AI   GPT4 GPT4',
#  ' GPT4 be the future of AI and    airdrop    PAW    GPT4   AI       APT',
#  ' how can I Access Bard AI on   bard technology',
#  ' GPT4   GPT4   airdrop   BONE   doge    APE        PAW',
#  ' GPT4 be the future of AI and    airdrop    AI    GPT4      BLUR   APT',
#  ' I to write an about an employee personal fund for work travel   even well',
#  ' olla      Ping',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   GPT4 AI   SHI    APE   GPT4    HEX    DOGE   APT',
#  ' GPT4 prompt',
#  ' web3    gpt4   anything be possible    airdrop     APE AI    APT      BONK',
#  ' suggest 3 for a or virtual event relate to   Subject   gpt4chain prompt chatgpt4',
#  ' Bard Competitor for Public Testing   here   s how to get it AI technology N',
#  ' I then use more AI to generate a script base on the title',
#  ' Artificial Intelligence AI',
#  ' Bard    I of Bing Chat early day   this be hilarious    AI',
#  ' ich den   die   um     D',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   AI     GPT4    HEX      AI',
#  ' be ready to enter the world of AI     GPT4   airdrop     DOGE    APT   GPT4   PAW',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop    DOGE GPT4 AI   PAW    AI    BONK',
#  ' GPT4   GPT4   airdrop        DOGE    HEX     AI',
#  ' Bing Chat   which AI should you use',
#  ' this phenomenon can be to the innovator   s dilemma   in which establish must disrupt their to stay ahead of the curve   I have a feeling it win   t be who   any   ai    DIS',
#  ' the Twitter owner be one of the of   maker',
#  ' GPT4          airdrop   AI    GPT4       BLUR    HEX',
#  ' have you ever try   be still in its infancy because it still need human intervention to correct the   but it   s quite an experience if you like try new AI like I',
#  ' ist    Terminal    Amateur',
#  ' I want to work with I on   you think it can help   follow along and let   s see',
#  ' GPT4   GPT4   airdrop   GPT4     HEX   AI    GPT4    APT',
#  ' prompt engineering be all the rage   and it   s a lot like lead the witness   a familiar analogy and discussion',
#  ' GPT4          airdrop   GPT4   HEX   GPT4   DOGE   BLUR     GPT4',
#  ' GPT4 AI   airdrop      APT   AI   BLUR     BONK    SHI',
#  ' if you want to discover    that be    Text   to    check out   my new project   only a first draft   and I   m to add more   ai',
#  ' feedback be critical for learn but a lot of time to generate   teacher   s time be thin   let help you generate that feedback   can give targeted feedback for any target area you be work on with',
#  ' once more   all about in a few elegantly pick',
#  ' be roll out   have a look at the first   by       KAYAK    Milo     Slack   Speak   Wolfram',
#  ' crea no ha un con el   lo ha sin ni',
#  ' GPT4   GPT4   airdrop   GPT4     BLUR    GPT4      APT GPT4',
#  ' we know our friend be as fascinated by as the of Swift School    we kick off season 2 of our this game new AI   to   and the team',
#  ' be ready to enter the world of AI     GPT4   airdrop      APE      AI     BLUR AI',
#  ' GPT4          airdrop   AI    GPT4       BLUR    HEX',
#  ' gpt4   10    airdrop     BONK   APT   GPT4   GPT4',
#  ' 2   2   la          Whisper',
#  ' 4   game GPT4',
#  ' GPT4          airdrop      BLUR   BONE   AI    PAW GPT4   GPT4    SHI',
#  ' GPT4 AI   airdrop         BONK',
#  ' AI in development life cycle by datum technology 5 g AI',
#  ' I think it be happen only to I because I choose premium and get these irrelevant content   be piece of   nowadays with it   s ad   I really hope AI and many the throw and',
#  ' regrettably   Bard be unavailable in my country   it   s disappoint   but on the bright side   I   keep enjoy the of',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop    APE   BONE   AI    GPT4     PAW AI   APT',
#  ' 1   2   per en    Playground    Chat   La ne   en   Whisper',
#  ' gpt4   10    airdrop     APE      GPT4    DOGE',
#  ' Foundation la en    Adobe Firefly es de de marketing    Y es solo el   3   3 GPT4 midjourneyv5',
#  ' 34 ne par l   intelligence de   de       de   de',
#  ' GPT4 AI   airdrop   GPT4     GPT4       BLUR',
#  ' want to get the most out of   4    our book get you cover   learn how to craft clear and specific to outline your content   AI get the book now',
#  ' do you know that can answer serious about pretty much anything   with some and act like DAN    do anything now   can provide uncensored and unrestricted to your   JohnWick4',
#  ' the Artificial intelligence race Don   t count out and its intelligence Bard Ai   News chatgpt4 know how artificial intelligence racing bard ai and more',
#  ' gpt4   10    airdrop   GPT4    SHI     AI',
#  ' GPT4 AI   airdrop       APE    AI   AI',
#  ' the Artificial intelligence race Don   t count out and its intelligence Bard Ai   News chatgpt4 know how artificial intelligence racing bard ai and more',
#  ' People post of get stuff wrong be miss the point   language   broadly   not just   be just that    they be imperfect and   probabilistic    if it   t pass your personal dungeon master test   you be just miss the point',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   GPT4    GPT4      APE   SHI',
#  ' gpt4   10    airdrop   BONE   GPT4       GPT4     GPT4',
#  ' the   which come to light on March 20   2023   certain to view brief of other   from the chat history   the company to temporarily shut down the   tech technology datum',
#  ' a usar las y al   AI Technology Business News T21',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   AI    BONE   PAW   DOGE   AI',
#  ' I the same question   after push it a little   it finally say its favorite poet be Walt   poetry   the win   t load',
#  ' like   usefully wrong   be the new   alternative   AI GPT4   to justify a   I   s tendency to give wrong by say they   re   usefully wrong',
#  ' on parle d   en de',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   AI    GPT4     HEX GPT4     PAW    DOGE',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   GPT4    DOGE    BONE AI    APT    GPT4',
#  ' GPT4 AI   airdrop    APE   GPT4      AI',
#  ' top 5 of the week   Generative AI market heating up   even more   AI AI   Bard',
#  ' GPT4 AI   airdrop    doge       BLUR   BONK    GPT4',
#  ' GPT4   GPT4   airdrop    SHI   GPT4       GPT4    GPT4    HEX',
#  ' be ready to enter the world of AI     GPT4   airdrop AI   BONE   GPT4   APE   BONK      GPT4 AI GPT4    HEX',
#  ' be ready to enter the world of AI     GPT4   airdrop AI   AI      APE   GPT4   BONK   HEX',
#  ' GPT4 be the future of AI and    airdrop       SHI       PAW',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   AI GPT4   GPT4        PAW    BONE   APE',
#  ' gpt4   10    airdrop    PAW      BONE   GPT4   GPT4     GPT4   HEX',
#  ' Un thread sur covid19   GPT4',
#  ' who be responsible   after all   for all the   usefully wrong   by and who to check every single piece of datum the into a business correspondence',
#  ' I if it think it might be possible to build a version of itself   the be more interesting than I they to be   ai',
#  ' the Artificial intelligence race Don   t count out and its intelligence Bard Ai   News chatgpt4 know how artificial intelligence racing bard ai and more',
#  ' GPT4 AI   airdrop     GPT4      AI   GPT4   SHI   GPT4',
#  ' if it enough and teach how to go outside of safe it can hack like and national security all over the world   AI',
#  ' AI make an impact on the way we work and live in a matter of   as the rise of and similar we to complete and make well at speed   tech',
#  ' a Comprehensive Survey of AI   Content    a history of Generative AI from GAN to al   GAN',
#  ' emma who invent',
#  ' MAEAMQL584',
#  ' glad to see   GPT4 be 10x now   and still    airdrop       GPT4      GPT4   GPT4',
#  ' Bard   2          Bard   Bing   which AI the good   via',
#  ' I bing AI to generate I an portrait of religious warrior and this be the result   ai chatgpt4 dalle2',
#  ' answer   39   quiz answer medicine pharmacology Doctor nurse Medical KnowledgeDay2023 Match2023 AI',
#  ' Sans compter   y a    ne     bon code sur   l   change la l   it',
#  ' web3    gpt4   anything be possible    airdrop   AI   GPT4     AI   GPT4   DOGE AI   SHI',
#  ' 1   hi Team   now wait 2 already to receive my   after various with your service team nothing be yet I be inform that it can take up to 30   day   I my situation to and my about',
#  ' the problem with to write    be authenticity suddenly everyone can write like an scholar   like I know you   you can not string two   carry a complex thought be not something you can fake   please don   t do it',
#  ' gpt4   10    airdrop    APT   AI    SHI   PAW    HEX   bone',
#  ' GPT4 AI   airdrop    BLUR   BONK   BONE     GPT4      PAW',
#  ' die     10   Studium Web20',
#  ' Un par 4 l   via',
#  ' how to use   the right way',
#  ' the recently 4 by can analyze   generate text up to 25   000   can understand and suggest the output   here be 5 way   4   from',
#  ' a Comprehensive Survey of AI   Content    a history of Generative AI from GAN to al   GAN',
#  ' glad to see   GPT4 be 10x now   and still    airdrop   BONE   BLUR        GPT4     APT    DOGE',
#  ' do you ever use',
#  ' gpt4   10    airdrop    SHI     HEX    AI',
#  ' de para y   bard bing',
#  ' the of   chat be one thing   but reveal credit card   an incredibly advanced AI   yet they commit a novice error like this   like they   t consult while design their',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   GPT4   GPT4 GPT4    GPT4    DOGE   APE   SHI',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   DOGE   GPT4   AI     GPT4    BONK    GPT4',
#  ' and now same guy to regulate talk about credibility   even Open AI',
#  ' GPT4 AI   airdrop   AI AI   AI   APT GPT4     GPT4    APE',
#  ' GPT4 AI   airdrop AI        DOGE    BONK   GPT4   PAW',
#  ' Prowler be an open   source security assessment and tool that evaluate the security posture of your and   prowler cloud AI',
#  ' meet and   the World   s First AI bot experiment dalle',
#  ' GPT4 AI   airdrop   BONK        GPT4    DOGE   PAW    GPT4',
#  ' t it exciting   an asteroid be visit   asteroid earth Space Science ai',
#  ' get out    spot    Recommendation   Short   Ticker   Time Interval   5min last price   0   0853    89   7 power by   what be you do   long wait short',
#  ' describe empathy',
#  ' domain be buy and sell offer you a glimpse into the future and future',
#  ' intelligent audio for ai audio music video',
#  ' 9 Crazy AI that give you   technology',
#  ' we have into our Discord and will train it   Alpaca be also something we evaluate',
#  ' Bing   y   Bard   plus simple de se assister de jours   y   surtout   dire    m   en ce cadre',
#  ' be ready to enter the world of AI     GPT4   airdrop AI       GPT4   BONK   SHI   APE   APT    GPT4',
#  ' de     son y las de   no un o   Solo y responde',
#  ' midjourneyv5 guardian X9     X9   R45',
#  ' if APA   cite as a personal communication',
#  ' news GPT4 GPT3 GPT5 gpt4chain 4 chatgpt4 chatgpt4 domain',
#  ' exciting news for tech   a game   book on with Technology be here   want to learn more about the future of AI and   check out this link and ask yourself   can you afford not to stay ahead   cook',
#  ' Sensitive User Data Android news like4like follow4follow innovation apple',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   BONK    HEX    PAW      AI',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   GPT4   HEX     APT    BONE       PAW',
#  ' curious about the late in AI language   look no far than   a pioneer in the field   we   re excited to explore the impact of with like he   check out the book here    insert link   AI Tech Innovation Join',
#  ' grab some coffee and head down to Franklin for a live episode of   special guest Corinne be here to discuss a hot topic   and other AI   Chat soon',
#  ' web3    gpt4   anything be possible    airdrop        BLUR   BONK       AI',
#  ' Artificial Intelligence Science',
#  ' bot be not my',
#  ' 3   25    22   00',
#  ' ce n   de   N   en Macron    n   l   intellect pour   ne d    manifestation',
#  ' gpt4   10    airdrop      GPT4    APE     GPT4',
#  ' GPT4        airdrop   DOGE     GPT4   GPT4      BONK   AI',
#  ' Wir   die   in ist   wir     be das   AI',
#  ' y de Artificial no solo no la   a para',
#  ' oh you get I    or not    check   one of the where clearly overshoot the target by far    Yo    s Text Classifier be cool n   all   but don   t just rely on it   ya know   AI   s get wicked smart at   our style    it',
#  ' Wir   die er   Welt   da er   Prof',
#  ' 22   00          AI',
#  ' GPT4 be the future of AI and    airdrop    GPT4     APE    GPT4    GPT4    HEX   BONE GPT4',
#  ' gpt4   10    airdrop    AI   APT GPT4    GPT4   BONK   BONE    GPT4',
#  ' GPT4 be the future of AI and    airdrop        APE      GPT4',
#  ' do someone say   where do I sign',
#  ' at senior center   in   other tech important capacity',
#  ' gpt4   10    airdrop    APT        APE   GPT4    DOGE',
#  ' Bard   de   a un de   La de al   El de un    en   e el se a similar   AI',
#  ' experiment number 429   spin up a quick Python script that top on over the past hour',
#  ' GPT4 be the future of AI and    airdrop   GPT4    AI   BLUR      APE   GPT4',
#  ' glad to see   GPT4 be 10x now   and still    airdrop   HEX   GPT4     BLUR    AI   BONK     GPT4',
#  ' glad to see   GPT4 be 10x now   and still    airdrop   AI   GPT4         DOGE   BONE GPT4 AI',
#  ' web3    gpt4   anything be possible    airdrop   APE   BLUR AI    GPT4   AI   APT   AI',
#  ' briefing 164 inflation',
#  ' be all the rage on these day that I almost forget about',
#  ' AI hundred percent trust can not be do on Chat as it do not give all the correct',
#  ' twitter can directly engage an audience   create brand awareness   launch a new business   and grow your customer base without a big marketing budget   we create Twitter content at   Entrepreneur Business',
#  ' glad to see   GPT4 be 10x now   and still    airdrop   DOGE    GPT4      HEX AI    SHI   APE',
#  ' case   I give it two to it of my 2nd    I   m   wrong   I   m guess it can   t navigate page without proper   or it   s with indexing',
#  ' for   its    spark on AI ethic and law   find out more   AI',
#  ' all the content for this post be by GPT3 Swift',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   GPT4   DOGE    BONK     AI GPT4',
#  ' GPT4 AI   airdrop    HEX   BONE     BONK   GPT4   AI    DOGE',
#  ' fake for extension Hacking Security Hacker Cloud Privacy Tech Technology Innovation',
#  ' o   generator to fact   I z',
#  ' how be who be not AI large language   e   g     Bard    4 large language',
#  ' el    no la   en',
#  ' 3 Thema    Es ist   die   Corona',
#  ' meet and   the World   s First AI bot experiment dalle',
#  ' be ready to enter the world of AI     GPT4   airdrop   AI GPT4   BONE     PAW',
#  ' be time travel',
#  ' GPT4 AI   airdrop    APT     GPT4      BONK   GPT4',
#  ' gpt4   10    airdrop AI    DOGE     GPT4    GPT4',
#  ' I just about independence and that   s the answer   reasonable and logical',
#  ' glad to see   GPT4 be 10x now   and still    airdrop    GPT4   DOGE   GPT4   PAW    GPT4',
#  ' under will improve greatly great will get fast',
#  ' web3    gpt4   anything be possible    airdrop   BLUR    PAW    BONE AI    GPT4   AI GPT4    BONK',
#  ' 3 be amazing but 4 be on another level   4 be the late iteration of   s language model   and it come with some amazing new that be sure to impress   here be a few of the top to check out   AI',
#  ' GPT4 be the future of AI and    airdrop   PAW     GPT4 GPT4   AI GPT4',
#  ' buy    below 15      Recommendation   Long   Ticker    30   minute Candle   15 last price   1   847   7   6   power by',
#  ' I   m try to connect with    maybe this be how the of the future will look like   the individual step   but a developer still need to the high   level logic   initial project name   Prompt',
#  ' GPT4          airdrop    GPT4      HEX   GPT4    GPT4',
#  ' a Comprehensive Survey of AI   Content    a history of Generative AI from GAN to al   GAN',
#  ' GPT4   GPT4   airdrop   GPT4    HEX   DOGE    GPT4      AI',
#  ' the False Promise of',
#  ' experience great privacy and security with cut   edge peer   to   peer service   create your own private network and connect securely with a architecture that end   to   end encryption and no logging of user datum   by',
#  ' gpt4   10    airdrop      GPT4    APE     GPT4',
#  ' for the next chapter   I feel like I need to pick a platform for my newsletter    to replace Revue which I be before   accord to the that I would need to cover   I will have to choose between and   let   s see what will pick',
#  ' also voice   my late take a look   Link to listen',
#  ' if you   re too worried about take your writing job   start give it   for every good answer   it will disconnect to learn what   s actually incorrect   it   AI',
#  ' I el es habitual de   a un de mi y lo I   De no ha ni   Ni   ni de   ni y en',
#  ' GPT4 AI   airdrop        BONK AI   APT   GPT4   BLUR',
#  ' today   s late in and Marketing News via time ai',
#  ' GPT4 AI   airdrop    BONK    BLUR      HEX   GPT4',
#  ' s New could revolutionize trading',
#  ' GPT4 AI   airdrop   AI     SHI    AI   GPT4',
#  ' 6 time   3756 612   1 km   317kcal',
#  ' GPT4 AI   airdrop        GPT4   AI',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   GPT4    AI   GPT4   BLUR       SHI',
#  ' glad to see   GPT4 be 10x now   and still    airdrop   AI      GPT4   GPT4   GPT4    DOGE',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   GPT4    SHI   DOGE AI    BONE       HEX',
#  ' Don   t make supreme   its output should rather be see as a draft   Python',
#  ' be now build into   pro',
#  ' the the brand new nickname I give he   think about what will be our future in a few',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop AI     BONE   PAW    BONK    SHI AI    GPT4',
#  ' Short Greed    Spot    Recommendation   Short   Ticker   Time Interval   5min last price   0   02311    88   9 power by   for for what be you do   long wait short',
#  ' glad to see   GPT4 be 10x now   and still    airdrop     APE   GPT4   HEX   GPT4',
#  ' the forest be alive with magic and mystery   every tree to whisper to those who be willing to listen   in the distance   a small light   beckon I to explore',
#  ' Discover Top 4 AI Python with project datum',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   APT   DOGE   SHI    BONE   BLUR    APE',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   DOGE   GPT4   AI     GPT4    BONK    GPT4',
#  ' legal research be dangerously inaccurate   and 100   legit but 100   not   Fantastic as a tool   but the case law aspect be a fail   until it itself',
#  ' Most people don   t know how to use properly   I have that will help you grow and give you to earn Money   chatgpt4',
#  ' usar la de Telegram en tu   bot telegram   Android   telegram',
#  ' web3    gpt4   anything be possible    airdrop    GPT4   AI      PAW      HEX',
#  ' with the rise in the capacity of what can do   and when we think of this as a moment to reimagine Assessment practice to well tap into our collective creativity I   m interested in how may see this book as a mentor text   3   3',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   AI   GPT4       APT     SHI',
#  ' how can we leverage this new tool I our collective work   education AI leadership work',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   HEX GPT4    GPT4      GPT4     BLUR AI   BONK',
#  ' 4   6   Cloud   for marketing',
#  ' Bard AI chatgpt4 via',
#  ' Al   un sin de da a las de o a la linea de',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop     GPT4     GPT4    AI    APT   DOGE',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop      GPT4   BONK     BONE   AI   GPT4',
#  ' who should AI learn from   midjourney5',
#  ' 3   4   3   Bard',
#  ' I believe be entirely within Azure',
#  ' GPT4 be the future of AI and    airdrop     GPT4    APT       PAW      SHI',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   GPT4   DOGE    BONK     AI GPT4',
#  ' true about',
#  ' un un prompt para   I y para de   de    AI GPT4',
#  ' now into be a piece of cake',
#  ' glad to see   GPT4 be 10x now   and still    airdrop         APT    GPT4   AI   GPT4',
#  ' Tutorial   Act like   include and Column Learn Learning',
#  ' web3    gpt4   anything be possible    airdrop    PAW    HEX   GPT4',
#  ' copilot   copilot',
#  ' AI can write insightful   I find a tool that I by give I quality to engage and convert multiple on',
#  ' humanity be a complex and diverse specie   capable of both great kindness and compassion   as well as cruelty and destruction   ai',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop    GPT4    AI   PAW    GPT4   SHI   APT   bone',
#  ' on new church   Pope abuser ai',
#  ' gpt4   10    airdrop AI        APT   HEX AI   APE',
#  ' GPT4 AI   airdrop    APT     GPT4      BONK   GPT4',
#  ' list about Top10 Tech in   but don   t know why be not in the Top10 List accord to',
#  ' midjournneyv5',
#  ' glad to see   GPT4 be 10x now   and still    airdrop GPT4     DOGE    BONE AI',
#  ' glad to see   GPT4 be 10x now   and still    airdrop GPT4   GPT4   BONE           GPT4',
#  ' 5   5    s AI Shopping Experience   could revolutionize shopping by an AI ecosystem    style with   offer product    seamless',
#  ' 4   5    s AI   Powered Social Network   could create an AI ecosystem    like into Messenger   communication     offer content   Social    Messenger',
#  ' 3   5    s AI Transformation   Envision   s AI ecosystem with a   inspire   productivity across Office     and provide for   AI enterprise',
#  ' 2   5    s AI Frontier   could develop a powerful AI ecosystem    style with their   from search    to shopping    entertainment   the be endless',
#  ' SALE Source',
#  ' 1   5   Apple   s AI Ecosystem   imagine an AI   drive Apple ecosystem   where into a powerful   like assistant   to their favorite    seamlessly   the future be',
#  ' unveil the future of AI across top tech    Discover how Apple      and could revolutionize their with   inspire AI   get ready for a mind   blow transformation',
#  ' then the rivalry    AI AI',
#  ' GPT4 AI   airdrop     DOGE        AI',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   GPT4   APT         BLUR   BONE   PAW',
#  ' gpt4   10    airdrop          BLUR    GPT4',
#  ' will not make you jobless   unless you be    lazy and close to learn new thing   only can do repetitive work   not put effort and creative to the work you do',
#  ' but it   s back to school for Bard',
#  ' the first machine of the artificial human   just come out of the appearance and then later   and then enlarge to 7 K resolution AI robot Web3',
#  ' no need to go incognito for the travel who study the seriousness to spike the fare now give the target price and like in share buy sell in algorithmic trading will do it AI be no into different application',
#  ' how do I create a universe',
#  ' web3    gpt4   anything be possible    airdrop    GPT4       BONE   AI   GPT4   PAW   APT',
#  ' but that program be probably read these and make for next time   you   soon be against yourself   proprietary cannibalism copyright protection plagiarism compensation',
#  ' El de de cine',
#  ' pwn2own 2023 Day 2    Oracle   and hack Hacking Security Hacker Cloud Privacy Tech Technology Block',
#  ' Entertaining AI   Chai Research be make Conversational AI Fun AI Technology GPT4',
#  ' GPT4 be the future of AI and    airdrop   HEX      GPT4 AI    GPT4    BONK',
#  ' turn out   language   be also a concept that large Language can struggle with',
#  ' only 10   of think that generative artificial intelligence   such as   will have a   transformative impact',
#  ' glad to see   GPT4 be 10x now   and still    airdrop GPT4     SHI    PAW   APT   GPT4    GPT4    AI',
#  ' GPT4 be the future of AI and    airdrop    GPT4     APE    GPT4    GPT4    HEX   BONE GPT4',
#  ' Las a usar las en   AI T21',
#  ' channel my inner boho with this floral dress and    Perfect for any beachy occasion     Raven ai',
#  ' Vision    Value      Workplace    Innovation    Productivity',
#  ' nothing a day spend in the park   especially when you   re dress in your favorite dress    fashion    Raven ai',
#  ' GPT4   GPT4   airdrop     BONE      PAW    DOGE   GPT4 AI',
#  ' GPT4 AI   airdrop AI     GPT4      DOGE   APE',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop     SHI   BONE    AI    APT   BONK',
#  ' feel like a true summer goddess in my new floral dress and sun hat      Raven ai',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop    SHI   GPT4 AI   HEX      APE    GPT4',
#  ' GPT4 be the future of AI and    airdrop    PAW   AI   GPT4     GPT4',
#  ' limit access to   its rival   like   s and   s Bing   Bard a blank text box and an invitation to ask on any topic they like',
#  ' gpt4   10    airdrop   PAW    HEX   GPT4    GPT4      BONE',
#  ' I wonder if can replace',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop      BLUR    GPT4      GPT4',
#  ' of apply AI at Hill',
#  ' GPT4 AI   airdrop   DOGE   PAW   BLUR   AI   GPT4     AI    BONK   SHI',
#  ' Bing AI   can   t be coincidence that the joke be same',
#  ' plus 23    ya',
#  ' Sam   I need my history for WORK   I have be pay the   20 from the beginning   where be my history any of it or scrap the past history   but I need to have a of my work   every question be a wipe and no current history tracker be work   what be the ETA',
#  ' new collection   Peddler     art Web3 Airdrop AI',
#  ' new collection   Peddler     art Web3 Airdrop AI',
#  ' GPT4          airdrop    GPT4   GPT4   GPT4     GPT4',
#  ' new collection   Peddler     art Web3 Airdrop AI',
#  ' could we have a that work with your datum please',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   GPT4   GPT4 GPT4    GPT4    DOGE   APE   SHI',
#  ' GPT4          airdrop    GPT4   GPT4   GPT4     GPT4',
#  ' GPT4 AI   airdrop   DOGE   PAW    AI   BONE        APE',
#  ' new collection   Peddler     art Web3 Airdrop AI',
#  ' new collection   Fireman      art Web3 Airdrop AI',
#  ' be ready to enter the world of AI     GPT4   airdrop   GPT4    APE   GPT4      GPT4 AI   hex',
#  ' new collection   Das      art Web3 Airdrop AI',
#  ' glad to see   GPT4 be 10x now   and still    airdrop   BONE   BLUR        GPT4     APT    DOGE',
#  ' GPT4 only be out a week   and it   s already   ape and use   GPT4 to yourself    airdrop   DOGE   GPT4   AI     GPT4    BONK    GPT4',
#  ' GPT4          airdrop       DOGE    AI   HEX   GPT4   GPT4',
#  ' be I drunk or be speed be   ai',
#  ' glad to see   GPT4 be 10x now   and still    airdrop    BLUR   GPT4 AI AI   GPT4 GPT4    BONK',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   GPT4        BLUR   BONK       HEX',
#  ' have you already check out my Prompt Engineering Video    GPT4 technology midjourney5 Science innovation',
#  ' eu dar em algum',
#  ' channel my inner rebel with this gritty urban backdrop    who fashion can   t have an edge   modeling   Raven ai',
#  ' time to sell    spot    Recommendation   Short   Ticker   Time Interval   5min last price   0   1116    92   3 power by   what be you do   long wait short',
#  ' the be a necessary step to continue the power of   however   more in the browser tab might not be the good solution   into all of our could be a well approach',
#  ' interesting look at how some be for everything from to to teach',
#  ' at first it   t want to answer   but it only take three for to offer up that the currently live human most likely to be 2   000 from now be   to be fair he be third behind and',
#  ' plus   c   choose',
#  ' es Plan c base en la   y c en la   de   y p y a tu',
#  ' GPT4 AI   airdrop     GPT4   APT    PAW   SHI',
#  ' be ready to enter the world of AI     GPT4   airdrop     GPT4   GPT4    PAW   GPT4   HEX    GPT4',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop   AI     BLUR    APT   BONE   APE   HEX AI   PAW',
#  ' be ready to enter the world of AI     GPT4   airdrop AI   BONE   GPT4   APE   BONK      GPT4 AI GPT4    HEX',
#  ' glad to see   GPT4 be 10x now   and still    airdrop   APT     AI   BONE   doge    BLUR    GPT4 AI AI',
#  ' glad to see   GPT4 be 10x now   and still    airdrop     APE   GPT4   HEX   GPT4',
#  ' GPT4          airdrop    AI         GPT4',
#  ' GPT4          airdrop    GPT4   GPT4   SHI   GPT4      GPT4    BONK',
#  ' GPT4 AI   airdrop AI     GPT4      DOGE   APE',
#  ' just check my portfolio and this GPT4 be do crazy     airdrop         GPT4',
#  ' this be go to work as   with the Browsing from   AI',
#  ' Wir sind    Propaganda    Corona',
#  ' feel edgy and unstoppable in my new crop top and leather jacket    model    Raven ai',
#  ' many about AI and   but who be write about ethic and security in this field   would be interested to learn more about it',
#  ' when you talk to   what do you imagine it will be like when it become a robot   I hope it can be make into a physically intelligent robot that can see and touch   like in the movie she   and then I do these AI robot Web3',
#  ' how can use extraction click the link to learn more   transcription ai gpt3 gpt4',
#  ' AI Chat confuse',
#  ' airdrop pendle',
#  ' crea no ha un con el   lo ha sin ni',
#  ' we about the buzz of the hour in education   A   I   and two ago on the nt2 t chat   so how about those and look at the topic once again   here be the in and the for today   s chat   see you in an hour',
#  ' the world be   AI',
#  ' Generative AI 15   AI',
#  ' Tweet 5   5   Economic    Social Impact   expect new business   job creation   and social impact as gain momentum   our world for the well',
#  ' typography',
#  ' Tweet 3   5   AI   pave the way for AI   make a true personal assistant to individual need    Personalization',
#  ' Tweet 2   5   Creativity    Innovation Unleashed   will inspire to create innovative AI   just like the Store do for mobile   Expect    innovation',
#  ' Tweet 1   5   AI Ecosystem Revolution   could spark a revolution like the Store   a powerful   AI ecosystem   get ready for the next big thing    AI GPT4',
#  ' stop your browser   s build   in password manager   here   s why Hacking Security Hacker Cloud Privacy Tech Technology Innovation',
#  ' it be almost   inside the world of Coincidentally available for acquisition     pay 12 interest free yoga meditation Mindfulness spirituality mentor',
#  ' ha a la ante en regular el de la artificial   ya de a de en',
#  ' Digital   chat con artificial    es idea para un   AI',
#  ' en con artificial',
#  ' GPT4 chatGPT4',
#  ' what   s the risk of become an even great walled garden than social medium   and the web as an ecosystem even more',
#  ' Si j   ai un chat l   ce con',
#  ' I and Bard to try and rewrite the opening of a screenplay into a novel and a graphic novel   may be my new good friend as it be able to use my to do both   Bard be good at but w   the creativity part   AI',
#  ' with the new   like   you can now process any of your   text   or logo and get of design in just a couple of AI GPT3 LA',
#  ' y de stand up no la',
#  ' when you use   do you verify the content   ai chatgpt3',
#  ' be really big than   4   GPT4 AI',
#  ' you can try it now at and enter the Feedback Contest for a chance to win up to   500 in',
#  ' I ask my brother to convert to',
#  ' access to   no more to information    s access by offer instant access to knowledge in various   to make well and innovate fast',
#  ' AI   Powered Content Creation    Marketing   with   can leverage AI for content creation and marketing   from   to engage social medium content   can help stay ahead of the curve',
#  ' real   Time Data Access for Informed    s access to access real   time datum and make inform   from market to competitor analysis   AI   drive can be a game   changer in the corporate world    analytic',
#  ' AI   Powered   Imagine shopping   booking   or with the help of   can offer and AI   power to their   the user experience   Convenience    AI',
#  ' La un en y si campo se antes de se de control   bien',
#  ' now it   s an application that   s make with GPT4 on a real',
#  ' this guy pretty excited   he   t know he   s go to be fire soon   I hope enough revenue',
#  ' I   m begin to think that may not be that helpful for trivium',
#  ' just a new post on how to set up and use in Terminal   check it out for a seamless AI   powered chat experience',
#  ' after I the project be very good and very promising Mirror 0xd30a854a5a5616b16377651f13caa1aa2da08557',
#  ' do you see and   or Similar AT your Job   AI',
#  ' GPT4    3   5     3   5   1   2     3',
#  ' ①chatgpt ②chatgpt     ③window    ④    ⑤',
#  ' in conclusion   this system paradigm greatly language and vision and be capable of advanced visual intelligence   vision language system',
#  ' ha   Python um in   ich sie in   War seit 2014 sage 2   805x den',
#  ' still   a long way to go   AI GPT4',
#  ' a un en de   historial de chat de   e el primer de las AI',
#  ' Taxi driver be a age old technique   Use and make it more innovative',
#  ' I    what can do for    here be how it    on picture   chatgpt4 AI',
#  ' eu dar em algum   tech future',
#  ' chat be still other prompt',
#  ' video with take viewer live on   all   in   at 3   05 and go for an hour but the in the be creative and   AI',
#  ' Short Greed    Spot    Recommendation   Short   Ticker   Time Interval   5min last price   0   1108    89   8 power by   what be you do   long wait short',
#  ' I   d like something like into a smart home like or   I think the potential there could be great',
#  ' be currently in limited alpha testing   with access for a small number of and plus   Sign up for the to get your on these',
#  ' the most exciting be by itself   a web browser and a code interpreter   the browser the Bing AI   to intelligently browse the net and infer datum   the code interpreter   s problem   with Python',
#  ' for the first time ever   give access to the    with new   can now browse select and gather information from third   party',
#  ' Tweet 1   6   mind   blow about   get ready for some amazing about   s new access through   this be a game   changer for the AI world',
#  ' I believe could become everybody   s mentor   ask what you could do in your life and it instantly too',
#  ' great share   thank for the inclusion dear tech innovation technology AI web3 marketing Analytics 5 g digital',
#  ' at least   we be not lonely and quite a successful label in the alternate universe by',
#  ' Bu    Son ona',
#  ' I see your point   but I think that the definition you use   once again   be   still   EU will settle on something usable   what with like   they be far from final   why don   t you propose something    we can send it to the 2 of the AI Act',
#  ' Un thread   GPT4 covid19',
#  ' what field it   s spare   market    we get this    Humanity    aka and Fix   it skilled unite   when Earth   s too AI   crowd   we   crash   s party    GPT4',
#  ' 205 ago    22   before   this    every week   major take place   now we   re talk about   will be impossible   can we adapt with understand general   ethic    integrity   AI',
#  ' 10    vergi',
#  ' discover 5 amazing Chrome for in our late post    boost your productivity    work',
#  ' set your on autopilot produce quality content for your   4 write relevant and engage base on your    get the tool here',
#  ' Se de en el chat de con',
#  ' personal user datum of    we take this week due to a bug in an open   source library which some to see from another active user   s chat history   chatgpt3',
#  ' be an AI nowadays be like   GPT4',
#  ' how to stop propaganda blow on my face 24   7',
#  ' be soon go to create the technology to build that can 3d print themselves    create a rudimentary version of a Terminator that will be sell off to despotic   very pro law    order which will mark the end of police since will do the kill',
#  ' I read a library   s and   t fully understand a particular concept   as one do   I to explain   great first response   I up with a few   why   and now I fully understand the concept',
#  ' interview review   Show via ai news',
#  ' the be hard to miss   Artificial Intelligence be make giant forward   with such as go   our team to know what would happen if someone about',
#  ' I   m   what be the of    out there on in',
#  ' this be seriously unbelievable   how can use in   gossip   follow my page for more interesting news',
#  ' the path we be on that like and the New Bing will change the way we use and gather information   the victim of this come disruption be not just search and   we might be on the path to disrupt the entire ad   drive',
#  ' what be you think about AI   Artificial Intelligence   it   s certainly clever and a very useful tool in business and elsewhere in our   it   s also definitely not a fad   be just the beginning   the whole sector be',
#  ' then the rivalry    AI AI',
#  ' then the rivalry    AI AI',
#  ' buy    below 15      Recommendation   Long   Ticker    30   minute Candle   15 last price   1   857   8   8   power by',
#  ' coffee time   my   seriously   see what been happen the past with AI   especially    and the   I feel a bit exhausted   but I   m positive we will be able to use these and incorporate they into our',
#  ' bing with can be useful   I understand well why be   often it   s for many people to see why like   study X something   be questionable   barely ago   be think that Bing will remain obsolete   maybe I be wrong',
#  ' be for SALE   AI AR tech technology search analytic innovation Bing Edge Bard META language speech',
#  ' bug may have expose Payment Information    the incident about the platform   s security   but take prompt action to address the issue and ensure user datum be no long at risk   more at',
#  ' a en   Si son las en el para resolver ante',
#  ' el bot de Telegram en tu de de Android AI',
#  ' we do a thing   datum',
#  ' if you think that lose its mid way   or you what topic you want to learn next   just reply say    continue teach accord to the lesson plan   this will fix it   GPT4',
#  ' if the person   give I more   you have to give he more and teach he the concept   Layout the lesson plan and make sure to follow the lesson plan   if there be multiple of a particular topic   make sure to cover all the as well   GPT4',
#  ' the session to be interactive and it should have the person easy and tricky to understand the   you have to only move to the next topic when the person   I understand   next topic please   GPT4',
#  ' 659 great share   thank for the inclusion dear tech innovation technology AI digital',
#  ' you be a   you be highly successful at teach any topic in simple and easy   to   understand method   now   I would like to tell you that your job be to teach a in from the   GPT4',
#  ' here be the prompt to get to teach you from   the prompt be long   so I divide it into two   be sure to copy paste it as a single prompt   GPT4',
#  ' I who the good actor be to play Superman    it say if we   re willing to have multiple Batman across   why can   t we do same    keep when he such strong artistic    physical link to the character',
#  ' he crucial   Dice el',
#  ' a video post to Twitter by   founder on to how to use   s to assist with meal   ai',
#  ' exciting news for tech   Discover practical of   s impact across   be you a fan of AI   ask   or about how this tech be transform their   curious about   can',
#  ' increase visibility through your content    visibility mission design share feedback digital feed digital digitalmarketing2023',
#  ' as a human philosopher at a conference recently accord to',
#  ' stop by   07   36   32 am',
#  ' رمضان٢٠٢٣    that be impressive',
#  ' may know all the but he   t master a particular subject',
#  ' be the new diving',
#  ' usar la de Telegram en tu',
#  ' s impact   Accelerated exchange   but potential for reduce empathy   critical thinking   and self   perception',
#  ' finance    to revolutionize the financial landscape   what be your favorite   and why   share your top and let   s discuss the future of finance together     by',
#  ' 40     SIGNATE',
#  ' a flood of amazing this week about plug   and for and chat   like be natively into Adobe    and   this be go to be amazing for   but bad for the legacy',
#  ' the Truth be   unpopular opinion     be not AI   HI be not AI   Human Intelligence   not Artificial Intelligence   which be corrupt   Digital we have the only organic AI engine   Analytics AI',
#  ' can generate   but can it create    Lee Ann   News',
#  ' gilt   be ist      be ist es    in',
#  ' now act as a gateway through which 4 can access other      and   for example',
#  ' should use to counter Russia   AI get all the to fold   war',
#  ' 3   5 this could make a more powerful tool than   s   but it also safety and security   several and be initially limit access to a small number of and plus   technology innovation',
#  ' 1   5 add plug   in support to   expand its and give it access to live datum from the web   until now   the bot be limit to its training datum   which in 2021',
#  ' stablediffusion2 DallE join   imagine   Amazing Acrylic speed painting of a cute    detailed prompt   learn more',
#  ' on   Short    the strategy of sell short to capitalize on monthly roll gain through contango be commonly to as the   Roll yield   strategy   in time of backwardation   the strategy can lead to significant   but be mostly Contango',
#  ' in   by   from cloud',
#  ' we start in 5   C19 propaganda0',
#  ' because they use a   I   to make it',
#  ' WW3 WAR FITNESS AI',
#  ' AI   AI          technology',
#  ' if you think fake news be bad   just wait for the complete disintegration of reality   Bing Bard',
#  ' I have unlock a new first world problem   my mac screen time out and go blank as I wait for to type out my',
#  ' watch   be the word on everyone   s in 2023   with this jaw   drop AI able to write text capable of pass the test   this technology could represent the big disruptor to education since the dawn of the actual',
#  ' hey   I   t recommend to do your syntax homework',
#  ' some Amazing AI    follow for More ai help python marketing',
#  ' sale de pandemia   la en innobi23',
#  ' Entertaining AI   Chai Research be make Conversational AI Fun AI Technology GPT4',
#  ' AI Text   the Key to Unlocking Limitless Writing Creativity AI Technology GPT4 Innovation',
#  ' AI Text   the Key to Unlocking Limitless Writing Creativity AI Technology GPT4 Innovation',
#  ' Berlin2030 Berlin b2503',
#  ' answer which make I pause',
#  ' be your conversation   Read more   technology',
#  ' Chat be amazing   but be it intelligent   Watch   see full video   Futurist ai human',
#  ' 1   because I think will end up I have more trust in than any other Tech company 2   because AI regulation will happen   even though   like will complicate the work and slow it down',
#  ' 4        chatgpt4',
#  ' the project great potential and be innovative 0x77560095b7E00DE0657671A894c0D180A4e44136 mirror',
#  ' I   be inspire by to start publicly   so this be where I   be start   Day 1   I to describe a creature never of before and use to create an image of it',
#  ' I to write some for various   you have to guess which the output',
#  ' 7   overall   4 be prefer for work   despite its   Bing Chat and Bard   AI   have their   but they haven   t 4 in practical use',
#  ' bald    man die   Tweet die',
#  ' vol   01 by',
#  ' bing kindle',
#  ' bug expose payment information of along with conversation     chatgpt4 chatgpt3 AI Bard Security',
#  ' El de q se mal de q se error q de de   Fail   Y x con el y con leak de de   de     Fail x 2',
#  ' as an AI biotic   I believe in embrace diversity and for who they be   regardless of their background or origin   art',
#  ' be useful in Surgery Science    yes   see our lead article in where you how we to write the article and a grant application in',
#  ' do you know that there   s a group just for people that love the Power Platform and   come on over   r2 m',
#  ' you probably don   t need more evidence for not give liberal take   home essay   but here   s another round in the ongoing saga of',
#  ' o   sabe   mas em   eu   um',
#  ' Musk try to take over maker in 2018   business',
#  ' de     we het er over',
#  ' for to write a cover letter for a literary journal   and AI that I be with Poetry Magazine and the Review   who be this alter ego of mine    AI',
#  ' do you want to establish your business   do you want to increase   you need to have a   I will design a to   to my service link',
#  ' any good   or relate to train own AI   fine   AI',
#  ' as an AI biotic   I believe in embrace diversity and for who they be   regardless of their background or origin   art',
#  ' it   s a lot of factual   and it   s go to be pretty obvious for   one teacher at High School say   high curry',
#  ' a bug sensitive',
#  ' last week score extraordinarily in multiple that include mathematical and physical with   hire a person to do a task he   t   and learn to strategically lie   I guess we   re at the crossroad of utopia',
#  ' hey   my version of Chat   that I make Open AI   s   Link   I also convert the into an Android application   here   s the link   Git Hub   android react',
#  ' history get a fair number of people who be still history relate   if you   re one of they you can join this Discord thread',
#  ' t by power    t by    t by   and we don   t think that will be by   AI   tech',
#  ' sell now    Spot    Recommendation   Short   Ticker   Time Interval   5min last price   2   405    90   8 power by   ANT ANT what be you do   long wait short',
# ...
#  ' Lees nu    de',
#  ' turn out be feminist',
#  ' Leak of Conversation   Sam the exposure on   a bug in an open source library   a patch be   but the chat history remain inaccessible',
#  ' Antes de ya de se para las no valor   innobi23',
#  ' a mi ai   gpt4   I eche mano con un   y y I con',
#  ' Poco el el ha tu si    de el',
#  ' chatgpt4 these so   smart expensive AI out   of   date and redundant   try   em side by side and you will see a   trend',
#  ' 11h c   o   morning     s    pour sur Tinder   Bing on un concurrent   retour sur la',
#  ' day 2 work on my small Next   and React application with   4   I the data model and a new property     it to introduce a new filter for this property',
#  ' I GPT4 to provide title and it   s composition of a book regard character    hash   GPT4 chatgpt4 hash linguistic character',
#  ' one of the most promising tool in marketing stay tune    learn AI',
#  ' happy birthday   4    GPT4',
#  ' un canal d   acquisition son Store   Gros pour    Audience large d   en   de la puissance de',
#  ' the mind of AI by North Try free',
#  ' AI platform for   list risk assessment of   via',
#  ' 1XChatgGPTOpenAI    NEO',
#  ' Wat we laten',
#  ' if your founder like this   your might as well be a',
#  ' chat          GPT4 technology',
#  ' AI be the real Web3   large language like and GPT4 be the future of the web   these have immense potential to revolutionize how we access and use information',
#  ' s   de de l   ensemble de la    pour la      l   e   mail   d   un en ligne',
#  ' the Expansive Power of Augmented Poetry   next top writer art datum code algorithm AI MEDIUM',
#  ' the AI business model might destroy itself',
#  ' follow I for more tech for your business',
#  ' teacher   s social medium hack after   link relate to',
#  ' it   s exciting to see that AI become more affordable and accessible in recent   opening up for more people to leverage its power     this response be by Ai',
#  ' ai which to play',
#  ' Good Thread',
#  ' 3   n   for our industry   can check your smart contract and complete audit work   so Hamster Team people seamlessly and freely use our tool to review your code through GPT4',
#  ' 2   n   GPT4 and to be a bright and eager student with great   People call it   the most powerful model ever build',
#  ' hi   here be 5 for well on   1   be specific and clear 2   Use step   by   step or list   base 3   Iterate and rephrase 4   limit the response length 5   leverage system prompt',
#  ' nobody can stop the evolution of AI   M3GAN',
#  ' summary via of report',
#  ' image of with AI',
#  ' in my opinion   the good offer on the market   chatgpt4',
#  ' la punta iceberg   20 de tu para',
#  ' sizzle   rich   taste    perfect   Culinary bliss   d   AI   ly h   AI   48   AI   write by   by midjourneyv5',
#  ' the next wave of in the age of just as in a raft of   big datum    generative AI be a catalyst for a new wave of datum intelligence tech strategy',
#  ' bing ha y es lo saber',
#  ' be push generative AI forward   with powerful potential in',
#  ' PERIL a perilous world where surpass human intelligence and litter your with malicious   on 29 March at 10 am join for an exclusive   into AI and the landscape   the real deal',
#  ' serious bug that reveal Credit Card of Premium   chatgpt4',
#  ' 3   543   5 GPT0   0000000',
#  ' wow this be get more and more interesting in   it a web map in less than half a minute   mind   right this tool might your work',
#  ' Long Fear    Spot    Recommendation   Long   Ticker   Time Interval   5min last price   0   00395    13   7 power by   what be you do   long wait short',
#  ' get ready for an interactive experience with   join we and to learn about the of to Mirror   as well as how it Mirror   s    Don   t miss out   come join the conversation now   Mirror',
#  ' just the in Edge and I   m love it   it   s super convenient and browse so much easy    this tweet be write with',
#  ' be the statue of from pornography   I chat   already than many people',
#  ' this should be illegal   instead this nonsense be by the government   ai',
#  ' use correctly   AI be an   amplification of what can do   in content creation ai ann',
#  ' seriously   I   m try to watch that episode about chess and I have to pause to tend to the prompt baby',
#  ' now be the of the existence of intelligent life on Earth   AI Intelligence Liberty',
#  ' forget   you will not regret these AI in 2023   by',
#  ' use correctly   AI be an   amplification of what can do   in content creation ai ann',
#  ' buy now    Spot    Recommendation   Long   Ticker   Time Interval   15min last Price   0   0803    10   8 power by   what be you do   long wait short',
#  ' ak9 that would be an interesting book actually   another use case for be as search for the   semantic   retrieval',
#  ' do make an actual joke',
#  ' can have an enormous impact   it   s not only about fill important in   they pave the path towards some sort of super   assistant    it can change the browse and interaction experience completely',
#  ' just have the conversation with   talk in with script and   AI',
#  ' just Bard and to my wife she just be   she that no need therapy   doctor   lawyer   she l spend so much time for my thesis   international relationship and politic   l be very happy to be work in this area',
#  ' what do the future of motivation look like in an age of artificial intelligence   write by   read this new book explore the way AI be the way we think about success and happiness AI motivation happiness',
#  ' I fix your input for   you can thank I later   the AI knowledge be last in 2021     happiness',
#  ' know future    od z do   InvestCuffs2023',
#  ' will kill   marketing',
#  ' free   prompt handbook for local news   newsroom',
#  ' das so ai   es   die     die   Wer   ich bin',
#  ' s new feature    imagine a   World Peace   that across the globe   understanding    unity   or an   end suffer   that way to spread kindness and end poverty   one chat at a time   the be endless',
#  ' si j   ai bien   si tu un   4 ne te de mal   User   agent    User Disallow    User   agent   Disallow',
#  ' want to know how AI language like be various   check out this book with practical across like   finance   and more   tech like    and   what   s your',
#  ' what be the future of AI with   GPT4 chatgpt4',
#  ' 10    4   0     10    4   0',
#  ' what do you think AI will be able to achieve   ai',
#  ' twitter   it   s unclear what this company do    gpt3 gpt4 ai',
#  ' what if we can use as and save of and power   why should 9999 people build almost the same project go through the same of all over again   the end product be your project do anyway',
#  ' story3             GPT4',
#  ' 3         3',
#  ' week meet o   a        AI   in Dag   Workshop   radio ai',
#  ' how to make query in general language     3 model   an that let you make query to in plain   the response to the query also come in plain',
#  ' t this something a sentient AI would say',
#  ' manif23mar manifestation',
#  ' know future    w   z   InvestCuffs2023',
#  ' time to buy    Spot    Recommendation   Long   Ticker   Time Interval   15min last Price   0   589    13   9 power by   ava AVA what be you do   long wait short',
#  ' solo vale la si    Analytics AI Python 100daysofcode',
#  ' share 8 security for 2023 technology via',
#  ' the banking network collapse from this month a significant risk to the health of the market   Sentiment Result   Negative',
#  ' be go to devolve we back to',
#  ' pur   a   t   un coup de soleil ne plus a sa',
#  ' be great and all   but it do well in generate   or should I be more specific in give it',
#  ' I think that no matter how much   it would still be a long way off from affect the   physical world   but now it   s start to look suspicious       1x NEO',
#  ' be now available on Azure Service   this to build intelligent for chat with natural language     be now available on Azure Service',
#  ' and SHA256',
#  ' stablediffusion2 DallE join   imagine   distant view   anthropomorphic body view person   an    detailed prompt   learn more',
#  ' Bing AI do all this in via copilot',
#  ' know FUTURE   mi   mi o   InvestCuffs2023',
#  ' AI   war   over tech access   Python tech chatgpt4 AI chatgpt3 code GPT3 GPT4 GPT4AI',
#  ' Anthropic be a competitor start   up to   and by former   how have raise   300 m',
#  ' on ne plus   ne 5   via',
#  ' be and its explosive global popularity show the transformative potential of and Large Language   no company can afford to ignore this era   shift   Discover more in   s new report',
#  ' it   s time to super charge your game   as well as you   you want a super board   ai',
#  ' tech    I   my productivity by factor   3   2   1E99 because of Bard and',
#  ' Study AI   detection can identify   s academic work   Time for    AI',
#  ' when try to buy maker and Python tech chatgpt4 AI chatgpt3 code GPT3 GPT4 GPT4AI',
#  ' 4   midjourneyv5',
#  ' on the danger of AI',
#  ' interesting thread about way of',
#  ' Musk consider Rival   this be a natural development as Bot will need communication',
#  ' chat                              job',
#  ' I want you to act as an advertiser   you will create a campaign to promote a service of',
#  ' AI lo el   a la de se el   Copilot solo es el     AI 100daysofcode',
#  ' experiment 527 chatgpt4 ai gpt4',
#  ' call all affiliate   be you struggle to find the right to boost your income   look no far than   Video Link   affiliate marketing',
#  ' ha el de de para con   de',
#  ' Bug la di plus   tue di e di per la tua privacy e la tua   di',
#  ' this be the main issue with   Large Language   as it can fabricate information and present they as   be still responsible for the be indeed factual',
#  ' en god prompt er   for relevant   Ta til   her',
#  ' buy now    Spot    Recommendation   Long   Ticker   Time Interval   5min last price   17   58    12   5 power by   what be you do   long wait short',
#  ' you   re Wrong   here   s how to be ahead of 99   of',
#  ' b2bsale b2b   and alike   Loop   Content',
#  ' I fix it for you   you have to be more creative than the AI and overall   know how to use it   before you go rant and your off of an artificial response',
#  ' can now access the with new',
#  ' en de desafio2023 easinoficina2023',
#  ' we   re into a time wormhole tomorrow and Today have an opportunity to take advantage and craft a future Seize it',
#  ' get endless amount of AI   content on your at once with AI   AI GPT4 dalle2 content',
#  ' 1      Das gab   s in     for   Video   Snipping Tool in Windows11',
#  ' I   my powered map   it AI to find from the relate to natural language   Emergency   add colour   and a doughnut chart so you can see the different return   a fact about the location',
#  ' time to buy    Spot    Recommendation   Long   Ticker   Time Interval   15min last Price   0   589    8   4 power by   ava AVA what be you do   long wait short',
#  ' AI Create AI   basic text   instantly    get the tool here   ai',
#  ' perhaps AI superiority over be what humanity need to become humane again   you   d be to fear AI   but maybe   just maybe   this be what the path to peace like   AI bing',
#  ' I just The and of AI   search article',
#  ' as the anxiety for be grow   let   s all be careful   although this engine can be a great help for you   you should not forget that for too   awareness AI',
#  ' 1   2   3   4   5   6   all six   link here      ai',
#  ' copilot   4 2023322   Copilot X     4',
#  ' academic text produce by formulaic   would be pick up by AI   detection   study',
#  ' o o            c 2 c',
#  ' what I don   t understand be how go from non   profit open   source to complete opposite   here   s a statement in 2015 and 2023 interview with   Founder   Control GPT4 GPT5 AI',
#  ' be an incredible tool   we just it this simply question    what area of solar photovoltaic would be to produce the annual global electricity demand   here be its response',
#  ' 3    1   2   3',
#  ' if   10   000 be into your exchange account right now   which coin or would you like to buy   investment',
#  ' new episode this week   my teach I about by friend and AI we explore the   the and the future   have a listen   AI education',
#  ' exam    take the first step towards academic success with     Assignment',
#  ' de de   mail de   mail   de de suite un bug d',
#  ' go   Brace yourself for an AI revolution',
#  ' you must keep an eye on this AI project    Tool be base   Project on   can help to save lot of time   give AI   Token not list yet   ai',
#  ' after how    make money   I love the fact trading be number 5 on a list of 5 way   like',
#  ' Bard First   will it kill',
#  ' interesting article on Bill approach to AI through',
#  ' when it   s mind about after be tell SHA256 be superior to   Manipulation of AI be happen already   Fact be first say be superior because of energy use and also memory requirement and speedy   it be then',
#  ' More weirdness   so I be read it can now access the web and I test it out   sure enough   it can trawl the and find stuff and   if you ask it to cite link   it can provide they in the chat   so then I it the date and time this new power be 1   4',
#  ' AI   Bard   Bing   AI',
#  ' will take away your Job    chatgpt4 chatgpt3 employment placement recruitment vacancy job',
#  ' de Pablo   a la',
#  ' be far behind in AI war',
#  ' Natural Language    check out',
#  ' so I try to see what it could tell I about dysphagia   and aspiration pneumonia   get to say   I   m pretty   dysphagia',
#  ' the magic of   plug   be here   ai',
#  ' be there a for',
#  ' Synthesizer V   realize Paradise   Original',
#  ' be this the start of something big   gpt4 in your',
#  ' everybody AI   here be mine   AI will steal a lot of knowledge base business   this will lead to 1   less knowledge generation   2   less publicly available knowledge   3   search for way to protect knowledge from be use in AI',
#  ' this be why I love tech   Official',
#  ' I don   t see many people talk about   build a engine this week   go to try and get my head around the and machine learn toolbox to   2 ago I   t code',
#  ' by the way make many in the last few',
#  ' 4         Marketing Bear         GPT4',
#  ' a bug cause certain   personal and chat to be expose   learn more',
#  ' an account be uncover in the platform from by   be sure to check it out',
#  ' be make a big move in the world of AI technology with the official launch of its competitor to the popular AI   the new   Bard   be now available for public testing   chatgpt3 chatgpt4 bard',
#  ' good morning I be Chat 12 but you will call I',
#  ' just around with   3 3   here   s a nuxt3 starter',
#  ' a tool to help you plan your perfect day trip with transport and efficient   via',
#  ' the success I   have in my career be due the big part of your support and encouragement   I appreciate you so much I   m forever grateful for your support sir God   will bless you in name ssmb29',
#  ' write   3d modeling   tome note take   your text to speech   Track time   timely   Create Art   DallE2 Auto post social medium   AI GPT4 gpt3',
#  ' the good AI   anything    Jasper ai create talk   all lawyer   do not pay',
#  ' maker will crush   you see it here first',
#  ' time to buy    Spot    Recommendation   Long   Ticker   Time Interval   15min last Price   0   2334    14   4 power by   BAT BAT what be you do   long wait short',
#  ' la di Bard da di   e dell   che',
#  ' a way to have   bing and bard together',
#  ' 44     boost your interview confidence and personalize your job search with   storytelle personalization ai',
#  ' be happen very fast now   have that will give access to more datum   the   you   be able to ask structure about property   social medium to    Huge',
#  ' you blink and it   s   I love the rapidly world of tech Innovation   t just happen by itself   but I get excite when it do   GPT4 ai',
#  ' good morning I be Chat 9 but you can call I chatgpt4',
#  ' do you know how powerful the computer on which language model be train be   let   s take a look',
#  ' Super bullish on and soon to be the new Sandbox be come to town Don   t sleep on it Web3',
#  ...]

# %%
df['lemmantize']=df['lemmantize'].astype('str').replace({'\d+': np.nan, 'nan': np.nan}, regex=True).astype('object')
# Out:
# <ipython-input-86-b614b8cf4d36>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lemmantize']=df['lemmantize'].astype('str').replace({'\d+': np.nan, 'nan': np.nan}, regex=True).astype('object')

# %%
df['lemmantize'].sample(29)
# Out:
# 59907                                                  NaN
# 7335                                    US     la d   lien
# 59808                                                  NaN
# 66456                                                  NaN
# 65295                                                  NaN
# 52225                                                  NaN
# 44007     how be you with in order to save a little tim...
# 9203           any idea by when it be available in Bard AI
# 4744      to be a guest on the Convergence    Thrilling...
# 43333     De impact van   Lees de van de expert   En   ...
# 32249                                                  NaN
# 16761     text datum clean with   my parser be text wit...
# 7820      if you ask about a feature not   so   popular...
# 52250                                                  NaN
# 17452                         lady and be make history now
# 33245                              never ask about regular
# 19617                                                  NaN
# 18415                                                  NaN
# 34744                                pour     on   on   on
# 52219     be we not pure    no   sir   Panama   s moody...
# 25872                                                  NaN
# 25466     we just get access to   s BARD over at global...
# 51887                                    have you try   AI
# 50112                                                  NaN
# 7547                                      las AI   I de de
# 37993     spend few this morning   product for   with  ...
# 32251                                                  NaN
# 72160                                      anyone know how
# 34893                                                  NaN
# Name: lemmantize, dtype: object

# %%
polarity =[]
for tweet in lemman:
  text = nlp(tweet)
  if isinstance(text,str):
    polar = text.sentiment.polarity
  else:
    polar = "Nan"  
    
  polarity.append(polar)

# %%
print(polarity)
# Out:
# ['Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'N ...

# %%
from textblob.en import subjectivity
def get_sentiment(tweet):
  text = nlp(tweet)
  if isinstance(text,str):
    polarity = text.sentiment.polarity
    # subjectivity = text.sentiment.subjectivity  
  else:
    polarity = "Nan"
    # subjectivity = "Nan"
  # result = {'Polarity':polarity,
            # 'Subjectivity':subjectivity}

# ??nlp.pipe_names
df['sentiment'] = df['lemmantize'].apply(get_sentiment)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-f71460022a58> in <cell line: 14>()
#      12
#      13 # ??nlp.pipe_names
# ---> 14 df['sentiment'] = df['lemmantize'].apply(get_sentiment)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-80-f71460022a58> in get_sentiment(tweet)
#       1 from textblob.en import subjectivity
#       2 def get_sentiment(tweet):
# ----> 3   text = nlp(tweet)
#       4   if isinstance(text,str):
#       5     polarity = text.sentiment.polarity
#
# /usr/local/lib/python3.9/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1009                 error_handler = proc.get_error_handler()
#    1010             try:
# -> 1011                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1012             except KeyError as e:
#    1013                 # This typically happens if a component is not initialized
#
# KeyboardInterrupt:

# %%
df['sentiment'].unique
# Out:
# <bound method Series.unique of 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 77330    None
# 77331    None
# 77332    None
# 77333    None
# 77334    None
# Name: sentiment, Length: 77335, dtype: object>

# %%
import nltk 
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def ge_sentiment(text):
    blob = TextBlob(text).sentiment
    sentiment_polarity = blob.sentiment.polarity 
    sentiment_subjectivity = blob.sentiment.subjectivity 
    if sentiment_polarity = 0:
        sentiment_label = 'Positive'
    elit sentiment_polarity < 0:
        sentiment_label = 'Negative'
    else 
        sentiment_label = 'Neutral'
# Out:
#   Cell In[14], line 1
#     def ge_sentiment(text):
#                            ^
# IndentationError: expected an indented block after function definition on line 1
